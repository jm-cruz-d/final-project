# %%
import pickle
import os
import cv2
import matplotlib.pyplot as plt
import glob
import numpy as np
import time
import keras
from keras import utils
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras import backend as K
from keras.models import load_model
from keras.callbacks import ModelCheckpoint
import pandas as pd
import numpy as np

# %%
from keras.models import load_model
from keras.models import model_from_json
import json

model = load_model('Checkpoint_05_0.96.hdf5')
#with open('./Buena/Model_0.95.h5.json','r') as f:
    #model_json = json.load(f)

#model = model_from_json(model_json)
#model.load_weights('./Buena/Model_0.95.h5')

# %%
path = 'DB.jpeg'
im = cv2.imread(path)
imres1 = cv2.resize(im,(256,256))
pred = model.predict(np.expand_dims(imres1,axis=0))[0]
plt.imshow(Image.fromarray(imres1.squeeze()))

# %%
dirs = ['atocha', 'alfonso_xii', 'museo_prado', 'schweppes', 'plaza_mayor', 'la_almudena', 'ayuntamiento', 'debod', 'puerta_alcala', 'ventas', 'banco_esp', 'jardin_botanico', 'palacio_cristal']

# %%
for i, p in enumerate(pred):
    if p > 0.5:
        print(dirs[i], p)
# Out:
# debod 0.5795631
